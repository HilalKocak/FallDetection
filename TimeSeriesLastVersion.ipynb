# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Aug  8 22:00:53 2020

@author: hilal
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from keras.preprocessing import sequence
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.layers import LSTM

from keras.models import load_model
from keras.callbacks import ModelCheckpoint
import glob

from sklearn.preprocessing import MinMaxScaler
# ignore warnings
import warnings
warnings.simplefilter(action='ignore')
path = '/content/drive/My Drive/Colab Notebooks/Tests/'

testdir = glob.glob(path+"*/")

# %%
targets=list()
sequences = list()

for i in range(0,len(testdir)):
    adlFallTest= glob.glob(testdir[i]+"Testler Export/" +"*/")
    for j in range(0, len(adlFallTest)):
            tests= glob.glob(adlFallTest[j]+"*/")
            for k in range(0,len(tests)):
                file_path= tests[k]+ '340537.txt'
                df = pd.read_csv(file_path, header=4, delimiter='\t')
                df.drop(columns=["Unnamed: 23","Counter", "Temperature","Pressure"], inplace=True)
                df.dropna(inplace = True)
                values = df.values
                if len(df)>0:
                    sequences.append(values)
                    if adlFallTest[j][65]=="8":
                        targets.append(0)
                    else:
                        targets.append(1)
                    

import random
random.Random(3).shuffle(targets)       
random.Random(3).shuffle(sequences)
                         
group2 = np.full((2214, 1), 2) #train
group3=np.full((553, 1), 3) #test
group1=np.full((553, 1), 1) #validation
groups = np.concatenate((group2,group3,group1), axis=0)
    
len_sequences=[]
for one_sequence in sequences:
  len_sequences.append(len(one_sequence))
pd.Series(len_sequences).describe()

to_pad = 950
new_seq = []
for one_seq in sequences:
    len_one_seq = len(one_seq)
    last_val = one_seq[-1]
    n = to_pad - len_one_seq
    to_concat = np.repeat(one_seq[-1], n).reshape(20, n).transpose() # ilk iki sütunu silmem gerek
    new_one_seq = np.concatenate([one_seq, to_concat])
    new_seq.append(new_one_seq)
final_seq = np.stack(new_seq)

seq_len = 945
final_seq=sequence.pad_sequences(final_seq, maxlen=seq_len, padding='post', dtype='float', truncating='post')
#Preparing the train, validation and test sets:

# %%
import seaborn as sns

import matplotlib.pyplot as plt
#plt.hist(targets)
plt.figure(figsize=(7,4))
#plt.title('Distribution of ADL and FALL')
plt.xlabel('class')
plt.ylabel('Count')

sns.countplot(targets, color="#0FA5FF")
plt.savefig('/content/drive/My Drive/Colab Notebooks/newhist.png', format='png', dpi=100)
plt.show()

# %%
file_path
# Out:
# '/content/drive/My Drive/Colab Notebooks/Tests/206/Testler Export/802-YurumeGeri/Test_2/340537.txt'

# %%
df.plot(subplots=False, legend=False)

# %%
len_sequences=[]
for one_sequence in sequences:
  len_sequences.append(len(one_sequence))
pd.Series(len_sequences).describe()
# Out:
# count    3335.000000
# mean      480.199100
# std        97.116044
# min        68.000000
# 25%       412.000000
# 50%       458.000000
# 75%       531.000000
# max       945.000000
# dtype: float64

# %%
adl=list()
fall=list()
for i in targets:
  if targets[i]==0:
    adl.append(targets[i])
  else:
    fall.append(targets[i])

# %%
import seaborn as sns

import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
#plt.title('Distribution of ADL and FALL')
plt.xlabel('Size of time series')
plt.ylabel('Count')
#sns.countplot(adl)
plt.hist(len_sequences, color= "#E11A1A")
plt.savefig('/content/drive/My Drive/Colab Notebooks/hist3.png', format='png', dpi=100)
plt.show()

# %%
df_adl=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Tests/206/Testler Export/803-TempoluYavasKosu/Test_2/340537.txt',header=4, delimiter='\t')
df_fall=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Tests/206/Testler Export/917-YataktanDusme/Test_2/340537.txt',header=4, delimiter='\t')
df_adl.tail()
# Out:
#      Counter  Temperature  VelInc_X  ...         Yaw  RSSI  Unnamed: 23
# 500    29357            0  0.387878  ... -140.524144 -39.0          NaN
# 501    29358            0  0.389319  ... -140.462654 -39.0          NaN
# 502    29359            0  0.391663  ... -140.379831 -39.0          NaN
# 503    29360            0  0.389022  ... -140.286249 -39.0          NaN
# 504    29361            0  0.387695  ... -140.129852 -39.0          NaN
#
# [5 rows x 24 columns]

# %%
f,ax = plt.subplots(figsize=(12, 5))


df_fall.VelInc_X.plot()
df_fall.VelInc_Y.plot()
df_fall.VelInc_Z.plot()
df_fall.Acc_X.plot()
df_fall.Acc_Y.plot()
df_fall.Acc_Z.plot()
df_fall.OriInc_x.plot()
df_fall.OriInc_y.plot()
df_fall.OriInc_w.plot()
df_fall.OriInc_z.plot()
df_fall.Gyr_X.plot()
df_fall.Gyr_Y.plot()
df_fall.Gyr_Z.plot()
df_fall.Mag_X.plot()
df_fall.Mag_Y.plot()
df_fall.Mag_Z.plot()
#df_fall.Pressure.plot()
df_fall.Roll.plot()
df_fall.RSSI.plot()
df_fall.Pitch.plot()
df_fall.Yaw.plot()
plt.legend({'VelInc_X','VelInc_Y','VelInc_Z','Acc_X','Acc_Y','Acc_Z','OriInc_x','OriInc_y','OriInc_z','OriInc_w','Gyr_X','Gyr_Y','Gyr_Z','Mag_X','Mag_Y','Mag_Z','Roll','RSSI','Pitch','Yaw'}, ncol=2, loc="top")
plt.savefig('/content/drive/My Drive/Colab Notebooks/FALL.png', format='png', dpi=300)

# %%
f,ax = plt.subplots(figsize=(12, 5))


df_adl.VelInc_X.plot()
df_adl.VelInc_Y.plot()
df_adl.VelInc_Z.plot()
df_adl.Acc_X.plot()
df_adl.Acc_Y.plot()
df_adl.Acc_Z.plot()
df_adl.OriInc_x.plot()
df_adl.OriInc_y.plot()
df_adl.OriInc_w.plot()
df_adl.OriInc_z.plot()
df_adl.Gyr_X.plot()
df_adl.Gyr_Y.plot()
df_adl.Gyr_Z.plot()
df_adl.Mag_X.plot()
df_adl.Mag_Y.plot()
df_adl.Mag_Z.plot()
#df_adl.Pressure.plot()
df_adl.Roll.plot()
df_adl.RSSI.plot()
df_adl.Pitch.plot()
df_adl.Yaw.plot()
plt.legend({'VelInc_X','VelInc_Y','VelInc_Z','Acc_X','Acc_Y','Acc_Z','OriInc_x','OriInc_y','OriInc_z','OriInc_w','Gyr_X','Gyr_Y','Gyr_Z','Mag_X','Mag_Y','Mag_Z','Roll','RSSI','Pitch','Yaw'}, ncol=2, loc="top")
plt.savefig('/content/drive/My Drive/Colab Notebooks/ADL.png', format='png', dpi=300)

# %%
train = [final_seq[i] for i in range(len(groups)) if (groups[i]==2)]
validation = [final_seq[i] for i in range(len(groups)) if groups[i]==1]
test = [final_seq[i] for i in range(len(groups)) if groups[i]==3]


train_target = [targets[i] for i in range(len(groups)) if (groups[i]==2)]
validation_target = [targets[i] for i in range(len(groups)) if groups[i]==1]
test_target = [targets[i] for i in range(len(groups)) if groups[i]==3]

train = np.array(train)
validation = np.array(validation)
test = np.array(test)


train_target = np.array(train_target)


validation_target = np.array(validation_target)


test_target = np.array(test_target)

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
#series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Tests/206/Testler Export/803-TempoluYavasKosu/Test_2/340537.txt',header=4, delimiter='\t',index_col=0, parse_dates=True, squeeze=True)

# %%
from keras.layers import Dropout
import tensorflow as tf


model = Sequential()
model.add(LSTM(128, input_shape=(seq_len, 20)))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(30, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='sigmoid'))
model.summary()
adam = tf.keras.optimizers.Adam(lr=0.001)
chk = ModelCheckpoint('best_model.pkl', monitor='val_acc', save_best_only=True, mode='max', verbose=1)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
history = model.fit(train, train_target, epochs=100, batch_size=100, callbacks=[chk], validation_data=(validation,validation_target))



#loading the model and checking accuracy on the test data
#model = load_model('best_model1.pkl')

from sklearn.metrics import accuracy_score
test_preds = model.predict_classes(test)
print("başarım", accuracy_score(test_target, test_preds))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               76288
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 30)                3870
#
#  batch_normalization_1 (Batc  (None, 30)               120
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 80,821
# Trainable params: 80,505
# Non-trainable params: 316
# _________________________________________________________________
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5174 - accuracy: 0.7412WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 11s 216ms/step - loss: 0.5174 - accuracy: 0.7412 - val_loss: 0.4846 - val_accuracy: 0.8047
# Epoch 2/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3315 - accuracy: 0.8577WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 181ms/step - loss: 0.3315 - accuracy: 0.8577 - val_loss: 0.4170 - val_accuracy: 0.8553
# Epoch 3/100
# 23/23 [==============================] - ETA: 0s - loss: 0.2919 - accuracy: 0.8726WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.2919 - accuracy: 0.8726 - val_loss: 0.3660 - val_accuracy: 0.8608
# Epoch 4/100
# 23/23 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.8907WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.2611 - accuracy: 0.8907 - val_loss: 0.3256 - val_accuracy: 0.8788
# Epoch 5/100
# 23/23 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9038WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.2382 - accuracy: 0.9038 - val_loss: 0.3000 - val_accuracy: 0.8861
# Epoch 6/100
# 23/23 [==============================] - ETA: 0s - loss: 0.2234 - accuracy: 0.9133WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.2234 - accuracy: 0.9133 - val_loss: 0.2747 - val_accuracy: 0.9132
# Epoch 7/100
# 23/23 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9237WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s
ARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.1042 - accuracy: 0.9598 - val_loss: 0.0972 - val_accuracy: 0.9620
# Epoch 24/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9684WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0942 - accuracy: 0.9684 - val_loss: 0.1000 - val_accuracy: 0.9620
# Epoch 25/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0879 - accuracy: 0.9670 - val_loss: 0.0943 - val_accuracy: 0.9656
# Epoch 26/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9661WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0953 - accuracy: 0.9661 - val_loss: 0.1056 - val_accuracy: 0.9693
# Epoch 27/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0853 - accuracy: 0.9670 - val_loss: 0.0870 - val_accuracy: 0.9711
# Epoch 28/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9779WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0744 - accuracy: 0.9779 - val_loss: 0.0911 - val_accuracy: 0.9693
# Epoch 29/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9770WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0672 - accuracy: 0.9770 - val_loss: 0.0806 - val_accuracy: 0.9729
# Epoch 30/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9752WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.0637 - accuracy: 0.9752 - val_loss: 0.0953 - val_accuracy: 0.9729
# Epoch 31/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0646 - accuracy: 0.9801WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.0646 - accuracy: 0.9801 - val_loss: 0.0908 - val_accuracy: 0.9711
# Epoch 32/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9788WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0643 - accuracy: 0.9788 - val_loss: 0.0887 - val_accuracy: 0.9729
# Epoch 33/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9756WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0689 - accuracy: 0.9756 - val_loss: 0.0752 - val_accuracy: 0.9693
# Epoch 34/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9783WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 181ms/step - loss: 0.0636 - accuracy: 0.9783 - val_loss: 0.1149 - val_accuracy: 0.9620
# Epoch 35/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9761WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0658 - accuracy: 0.9761 - val_loss: 0.0923 - val_accuracy: 0.9656
# Epoch 36/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9697WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 182ms/step - loss: 0.0746 - accuracy: 0.9697 - val_loss: 0.1091 - val_accuracy: 0.9638
# Epoch 37/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9724WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0743 - accuracy: 0.9724 - val_loss: 0.1258 - val_accuracy: 0.9656
# Epoch 38/100
#  8/23 [=========>....................] - ETA: 2s - loss: 0.0576 - accuracy: 0.9775

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               76288
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 30)                3870
#
#  batch_normalization_1 (Batc  (None, 30)               120
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 80,821
# Trainable params: 80,505
# Non-trainable params: 316
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=False,
    show_layer_names=False,
    rankdir="TB",
    expand_nested=False,
    dpi=100,
)

# %%
from sklearn.metrics import accuracy_score
test_preds = model.predict_classes(test)
print("başarım", accuracy_score(test_target, test_preds))

# %%
'''from keras.models import load_model
model=load_model('/content/drive/My Drive/Colab Notebooks/modelfalladl.py')'''

# %%
#model.save('/content/drive/My Drive/Colab Notebooks/modelfalladl.py')

# %%
from tensorflow.keras.optimizers import Adam


adam = Adam(lr=0.001)
chk = ModelCheckpoint('best_model.pkl', monitor='val_acc', save_best_only=True, mode='max', verbose=1)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
history = model.fit(train, train_target, epochs=100, batch_size=100, callbacks=[chk], validation_data=(validation,validation_target))



#loading the model and checking accuracy on the test data
#model = load_model('best_model1.pkl')
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 8s 218ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0846 - val_accuracy: 0.9837
# Epoch 2/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9964WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0087 - accuracy: 0.9964 - val_loss: 0.1275 - val_accuracy: 0.9783
# Epoch 3/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9959WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.1322 - val_accuracy: 0.9765
# Epoch 4/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9968WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0071 - accuracy: 0.9968 - val_loss: 0.1084 - val_accuracy: 0.9801
# Epoch 5/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0874 - val_accuracy: 0.9855
# Epoch 6/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.1152 - val_accuracy: 0.9837
# Epoch 7/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9941WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0220 - accuracy: 0.9941 - val_loss: 0.0900 - val_accuracy: 0.9837
# Epoch 8/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9914WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0227 - accuracy: 0.9914 - val_loss: 0.1032 - val_accuracy: 0.9765
# Epoch 9/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9973WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0851 - val_accuracy: 0.9801
# Epoch 10/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9955WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0117 - accuracy: 0.9955 - val_loss: 0.0892 - val_accuracy: 0.9837
# Epoch 11/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.1065 - val_accuracy: 0.9765
# Epoch 12/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9982WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0893 - val_accuracy: 0.9801
# Epoch 13/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.1044 - val_accuracy: 0.9801
# Epoch 14/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9959WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.1053 - val_accuracy: 0.9819
# Epoch 15/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9977WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.1246 - val_accuracy: 0.9729
# Epoch 16/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0960 - val_accuracy: 0.9819
# Epoch 17/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0878 - val_accuracy: 0.9801
# Epoch 18/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.0868 - val_accuracy: 0.9837
# Epoch 19/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9982WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s
100
# 23/23 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1416 - val_accuracy: 0.9765
# Epoch 92/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.1480 - val_accuracy: 0.9747
# Epoch 93/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9923WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0214 - accuracy: 0.9923 - val_loss: 0.1173 - val_accuracy: 0.9747
# Epoch 94/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9932WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0185 - accuracy: 0.9932 - val_loss: 0.1142 - val_accuracy: 0.9801
# Epoch 95/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.1455 - val_accuracy: 0.9819
# Epoch 96/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9955WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 0.1429 - val_accuracy: 0.9819
# Epoch 97/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9977WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0123 - accuracy: 0.9977 - val_loss: 0.1535 - val_accuracy: 0.9819
# Epoch 98/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9946WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0114 - accuracy: 0.9946 - val_loss: 0.1517 - val_accuracy: 0.9693
# Epoch 99/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9982WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.1569 - val_accuracy: 0.9801
# Epoch 100/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.1309 - val_accuracy: 0.9801

# %%
from sklearn.metrics import accuracy_score
test_preds = model.predict(test)

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Test'], loc='upper left')

plt.subplot(2,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Test'], loc='upper left')
plt.savefig('/content/drive/My Drive/Colab Notebooks/yeni7.png', format='png', dpi=300)

plt.show()
# Do the plot code

# %%
#from sklearn.metrics import confusion_matrix,classification_report

#print(confusion_matrix(test_target,test_preds))
#print(classification_report(test_target,test_preds))

# %%
conf = confusion_matrix(test_target, test_preds)
TP = conf[0,0]
FP = conf[0,1]
TN = conf[1,0]
FN = conf[1,1]

# %%
FP

# %%
TN

# %%
FN

# %%
TP

# %%
def get_roc_curve(y_test, y_proba, delta=0.1):
    """
    Return the True Positive Rates (TPRs), False Positive Rates (FPRs), 
    and the threshold values, seperated by delta.
    """
    thresh = list(np.arange(0, 1, delta)) + [1]
    TPRs = []
    FPRs = []
    y_pred = np.empty(y_proba.shape)
    for th in thresh:
        y_pred[y_proba < th] = 0
        y_pred[y_proba >= th] = 1
        
        # confusion matrix from the function we defined
        (TN, FP), (FN, TP) = confusion_matrix(test_target, test_preds)
        
        TPR = TP / (TP + FN)  # sensitivity
        FPR = FP / (FP + TN)  # 1 - specificity
        TPRs.append(TPR)
        FPRs.append(FPR)
    return FPRs, TPRs, thresh

# %%
delta = 0.001
FPRs, TPRs, _ = get_roc_curve(test_target, test_preds, delta)

# %%
# Plot the ROC curve
plt.plot(FPRs, TPRs, color='red',
         lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label="Mean")
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC curve (threshold delta = {delta})')
plt.legend(loc="lower right")
plt.show()
